# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Introduction to Probability Distribution**

# %% [markdown]
# In this homework, you will familiarize yourself with the normal probability distributions and work on some exercises

# %% [markdown]
# ***

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# All Libraries required for this homework are listed below. So install them if you haven’t done yet, you may need to uncomment and install them.

# %%
#install latest version of libraries used in this homework
#! pip install pandas
#! pip install numpy
#! pip install scipy
#! pip install matplotlib
#! pip install statsmodels

# %% [markdown]
# Import the libraries we need for the lab

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
from math import sqrt

# %% [markdown]
# Read the CSV file using pandas

# %%
PATH = "./file.csv"
dataFrame = pd.read_csv(PATH)
dataFrame = dataFrame.drop(['Unnamed: 0'], axis=1)
dataFrame.head()
# Out:
#   minority  age  gender credits    beauty  eval division native tenure  \
# 0      yes   36  female    more  0.289916   4.3    upper    yes    yes
# 1      yes   36  female    more  0.289916   3.7    upper    yes    yes
# 2      yes   36  female    more  0.289916   3.6    upper    yes    yes
# 3      yes   36  female    more  0.289916   4.4    upper    yes    yes
# 4       no   59    male    more -0.737732   4.5    upper    yes    yes
#
#    students  allstudents  prof  PrimaryLast  vismin  female  single_credit  \
# 0        24           43     1            0       1       1              0
# 1        86          125     1            0       1       1              0
# 2        76          125     1            0       1       1              0
# 3        77          123     1            1       1       1              0
# 4        17           20     2            0       0       0              0
#
#    upper_division  English_speaker  tenured_prof
# ...

# %%
dataFrame.shape
# Out:
# (463, 19)

# %% [markdown]
# ## Introduction to Probability Distribution

# %% [markdown]
# In this section, you will learn how to create the plot distributions using the scipy library in python

# %% [markdown]
# ### Normal Distribution [More](https://en.wikipedia.org/wiki/Normal_distribution)

# %% [markdown]
# A normal distribution is a bell-shaped density curve described by its mean μ and standard deviation σ. The curve is symmetrical and centered around it's mean. A normal distribution curve looks like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can visualize the curve. Import norm from scipy.stat and plot graph with matplotlib

# %%
from scipy.stats import norm

# Plot between -6 and 6 with 0.1 steps.
x_axis = np.arange(-6, 6, 0.1)

# Mean = 0, SD = 1.5
plt.plot(x_axis, norm.pdf(x_axis, 0, 1.5))
plt.show()

# %% [markdown]
# ### Example 1: what is the probability of receiving an evaluation score of greater than 4?
# Find the mean and standard deviation

# %%
eval_mean = round(dataFrame['eval'].mean(), 3)
eval_sd = round(dataFrame['eval'].std(), 3)
print(eval_mean, eval_sd)
# Out:
# 3.998 0.555

# %% [markdown]
# Use the scipy.stats module. Because python only looks to the left i.e. less than, we do remove the probability from 1 to get the other side of the tail

# %%
prob0 = scipy.stats.norm.cdf((4 - eval_mean)/eval_sd)
print(1 - prob0)
# Out:
# 0.49856237327221

# %% [markdown]
# ## Question

# %% [markdown]
# ### Question 1: what is the probability of receiving an evaluation score greater than 3.5 and less than 4.2?

# %%
# Your code here
#
#
#
#

# %% [markdown]
# ### Question 2: what is the probability of receiving an evaluation score greater than 3.3?

# %%
# Your code here
#
#
#
#

# %% [markdown]
# ### Question 3: what is the probability of receiving an evaluation score between 2 and 3?

# %%
# Your code here
#
#
#
#

# %% [markdown]
# ### Question 4: To test the hypothesis that sleeping for at least 8 hours makes one smarter, 12 people who have slept for at least 8 hours every day  for the past one year  have their IQ tested.
#
# *   Here are the results: 116, 111, 101, 120, 99, 94, 106, 115, 107, 101, 110, 92
# *   Test using the following hypotheses: H0: μ = 100 or Ha: μ > 100

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Your code here
#
#
#
#

# %% [markdown]
# Double-click **here** for a hint.
#
# <!-- The hint is below:
# ### find the mean and standard deviation of the 12 IQs
# iq_mean = np.mean([116, 111, 101, 120, 99, 94, 106, 115, 107, 101, 110, 92])
# iq_std = np.std([116, 111, 101, 120, 99, 94, 106, 115, 107, 101, 110, 92])
# -->

# %% [markdown]
# ## Authors

# %%
# your names
